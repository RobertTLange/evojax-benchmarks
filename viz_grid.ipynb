# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

from mle_hyperopt.utils import load_search_log, visualize_2D_grid

# %% [markdown]
# ## Visualize Grid Search Results for ARS

# %%
df = load_search_log("log/ARS/cartpole_easy/search_log.yaml")

visualize_2D_grid(
    df, 
    params_to_plot=['es_config/init_stdev',
                    'es_config/optimizer_config/lrate_init'],
    plot_title="ARS Search on CartPole-Easy",
    xy_labels=["lrate_init", "init_stdev"],
    round_ticks=3,
    min_heat = 400,
    fname="figures/ARS/cartpole_easy.png")

# %%
df = load_search_log("log/ARS/cartpole_hard/search_log.yaml")

visualize_2D_grid(
    df, 
    params_to_plot=['es_config/init_stdev',
                    'es_config/optimizer_config/lrate_init'],
    plot_title="ARS Search on CartPole-Hard",
    xy_labels=["lrate_init", "init_stdev"],
    round_ticks=3,
    min_heat = 400,
    fname="figures/ARS/cartpole_hard.png")

# %%
df = load_search_log("log/ARS/mnist/search_log.yaml")

visualize_2D_grid(
    df, 
    params_to_plot=['es_config/init_stdev',
                    'es_config/optimizer_config/lrate_init'],
    plot_title="ARS Search on MNIST",
    xy_labels=["lrate_init", "init_stdev"],
    round_ticks=3,
    min_heat = 0.5,
    fname="figures/ARS/mnist.png")
